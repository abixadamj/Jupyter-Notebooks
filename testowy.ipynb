# %%
import numpy as np

# %%
x = np.linspace(-5,5,200)
y = np.sin(x)

# %% [markdown]
# OK, teraz *test*

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
np.dot(np.array([1,-1]),np.array([1,1]))
# Out:
# 0
